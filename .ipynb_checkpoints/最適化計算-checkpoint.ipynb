# %%
import pulp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# %% [markdown]
# # データを用意

# %%
# データをロード
df_constraint = pd.read_csv('下限値・上限値.csv', index_col=0)
df_data = pd.read_csv('単位あたりの価格・栄養成分.csv', index_col=0)

# スペースがあるとエラーが出るので置換する
df_data.columns = df_data.columns.map(lambda x: x.replace(' ', '-'))
df_constraint.index = df_constraint.index.map(lambda x: x.replace(' ', '-'))

# 最小化対象
objective_name = '価格（税込）'

# 表示
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)
display(
    df_data,
    df_constraint.T,
)
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
#                             食品情報_食品名     価格（税込）  総カロリー_エネルギー_kcal  \
# 食品情報_食品ID
#  101088                           ご飯   0.165000             1.681
#  104029                          きな粉   0.752000             4.429
#  200134                      わかめの味噌汁  17.120000            34.000
#  106267                       ほうれんそう   0.640000             0.200
# -1                                 塩   0.009700             0.003
#  113010                       スキムミルク   1.327000             3.589
#  114001                      オリーブオイル   0.983000             9.250
# -2                              えごま油   0.396667             0.921
# -3         ネイチャーメイド スーパーマルチビタミン&ミネラル   7.375000             1.665
# -4                  ネイチャーメイド ベータカロテン   5.414286             1.450
#
#            三大栄養素_タンパク質_g  三大栄養素_脂質_g  三大栄養素_炭水化物_g  ビタミン_ビタミンA_μg  \
# 食品情報_食品ID
#  101088            0.025       0.003        0.3710          0.000
#  104029            0.356       0.234        0.3100          0.000
#  200134            2.000       0.440        5.8600          2.990
#  106267            0.022       0.004        0.0310          3.500
# -1                 0.000       0.000        0.0007          0.000
#  113010            0.340       0.010        0.5330          0.060
#  114001            0.000       1.000        0.0000          0.150
# -2                 0.000       0.100        0.0000          0.002
# -3                 0.000       0.000        0.3355        225.000
# -4                 0.073       0.122        0.0000        150.000
#
#            ビタミン_ビタミンD_μg  ビタミン_ビタミンE_mg  ビタミン_ビタミンK_μg  ビタミン_ビタミンB1_mg  \
# 食品情報_食品ID
#  101088              0.0         0.0000          0.000           0.000
#  104029              0.0         0.0100          0.370           0.007
#  200134              0.0         0.0500         32.960           0.030
#  106267              0.0         0.0210          2.700           0.001
# -1                   0.0         0.0000          0.000           0.000
#  113010              0.0         0.0000          0.000           0.003
#  114001              0.0         0.0740          0.420           0.000
# -2                   0.0         0.0024          0.005           0.000
# -3                   5.0         4.5000          0.000           0.750
# -4                   0.0         0.0000          0.000           0.000
#
#            ビタミン_ビタミンB2_mg  ビタミン_ナイアシン_mg  ビタミン_ビタミンB6_mg  ビタミン_ビタミンB12_μg  \
# 食品情報_食品ID
#  101088             0.000          0.002           0.000            0.000
#  104029             0.003          0.019           0.006            0.000
#  200134             0.030          1.640           0.020            0.490
#  106267             0.002          0.006           0.001            0.000
# -1                  0.000          0.000           0.000            0.000
#  113010             0.016          0.011           0.003            0.018
#  114001             0.000          0.000           0.000            0.000
# -2                  0.000          0.000           0.000            0.000
# -3                  0.850          7.500           1.000            1.500
# -4                  0.000          0.000           0.000            0.000
#
# 食品情報_食品ID
#  101088             0.0010        0.0030        0.0010
#  104029             0.1260        0.2060        0.0340
#  200134             0.2400        0.3700        0.0700
#  106267             0.0020        0.0020        0.0000
# -1                  0.0000        0.0000        0.0000
#  113010             0.0000        0.0070        0.0040
#  114001             0.0720        0.9460        0.1330
# -2                  0.0706        0.0952        0.0076
# -3                  0.0000        0.0000        0.0000
# -4                  0.0000        0.0000        0.0000
# 栄養素名  総カロリー_エネルギー_kcal  三大栄養素_タンパク質_g  ビタミン_ビタミンA_μg  ビタミン_ビタミンD_μg  \
# 下限値             2500.0           60.0          600.0            8.5
# 上限値             2600.0          125.0         2700.0          100.0
#
# 栄養素名  ビタミン_ビタミンE_mg  ビタミン_ビタミンK_μg  ビタミン_ビタミンB1_mg  ビタミン_ビタミンB2_mg  \
# 下限値             6.0          150.0            1.35             1.5
# 上限値           850.0            NaN             NaN             NaN
#
# 栄養素名  ビタミン_ナイアシン_mg  ビタミン_ビタミンB6_mg  ビタミン_ビタミンB12_μg  ビタミン_葉酸_μg  \
# 下限値            14.4            1.42              2.4       240.0
# 上限値            80.0           55.00              NaN       900.0
#
# 栄養素名  ビタミン_パントテン酸_mg  ビタミン_ビオチン_μg  ビタミン_ビタミンC_mg  ミネラル_カリウム_mg  \
# 下限値              5.0          50.0          100.0        2500.0
# 上限値              NaN           NaN            NaN           NaN
#
# 栄養素名  ミネラル_カルシウム_mg  ミネラル_マグネシウム_mg  ミネラル_リン_mg  ミネラル_鉄_mg  ミネラル_亜鉛_mg  \
# 下限値           664.3           334.8      1000.0        7.1       10.62
# 上限値          2500.0             NaN      3000.0       50.0       40.00
#
# 栄養素名  ミネラル_銅_mg  ミネラル_マンガン_mg  ミネラル_ヨウ素_μg  ミネラル_セレン_μg  ミネラル_クロム_μg  \
# 下限値        0.81           3.5        130.0         30.8         10.0
# 上限値        7.00          11.0       3000.0        450.0        500.0
#
# 栄養素名  ミネラル_モリブデン_μg  その他_食塩相当量_g  その他_食物繊維-総量_g  脂肪酸_n-3系-多価不飽和_g  \
# 下限値            30.0          2.0           19.8               2.5
# 上限値           600.0          7.5            NaN               NaN
#
# 栄養素名  脂肪酸_n-6系-多価不飽和_g  脂肪酸_脂肪酸-飽和_g
# 下限値                5.0           NaN
# 上限値                NaN          19.4

# %% [markdown]
# # 計算実行

# %%
# 問題宣言
problem = pulp.LpProblem("問題", pulp.LpMinimize)

# 変数宣言
var_ary = [pulp.LpVariable(f'var{i}', 0, sys.maxsize, pulp.LpInteger) for i in range(df_data.shape[0])]

# 目的関数
problem += pulp.lpDot(df_data[objective_name].tolist(), var_ary)

# 制約条件
for constraint_name in df_constraint.index:
    mn, mx = df_constraint.loc[constraint_name, :]
    total = pulp.lpDot(df_data[constraint_name].tolist(), var_ary)
    if mn == mn:
        problem += ( mn <= total , f'{constraint_name}の下限' )
    
    if mx == mx:
        problem += ( total <= mx , f'{constraint_name}の上限' )
    


# ------------------------------------------------------------------------------------------
# 追加で制約
# ------------------------------------------------------------------------------------------

# n-6 / n-3 比
total_n_3 = pulp.lpDot(df_data['脂肪酸_n-3系-多価不飽和_g'].tolist(), var_ary)
total_n_6 = pulp.lpDot(df_data['脂肪酸_n-6系-多価不飽和_g'].tolist(), var_ary)
problem += ( total_n_6 <= 2 * total_n_3 , f'n-6/n-3' )

# ネイチャーメイドは1粒（2*0.5粒）まで
i = df_data['食品情報_食品名'].tolist().index('ネイチャーメイド スーパーマルチビタミン&ミネラル')
problem += ( var_ary[i] <= 2, f'ネイチャーメイド スーパーマルチビタミン&ミネラル は1粒まで' )

# わかめの味噌汁は一杯にする
# ほうれんそうや塩をまとめて食べられて楽なので
# 「カットわかめ」におきかえた場合と価格があまり変わらない
# （わかめの味噌汁の方が数円高い）
i = df_data['食品情報_食品名'].tolist().index('わかめの味噌汁')
problem += ( 1 == var_ary[i], f'わかめの味噌汁 は一杯' )

# オリーブオイルで一価と多価を同量にする
total_1 = pulp.lpDot(df_data['脂肪酸_脂肪酸-多価不飽和_g'].tolist(), var_ary)
total_2 = pulp.lpDot(df_data['脂肪酸_脂肪酸-一価不飽和_g'].tolist(), var_ary)
problem += ( total_1 <= total_2 , f'オリーブオイルで一価と多価を同量にする' )

# ------------------------------------------------------------------------------------------



# 問題表示
print(problem)

# 計算
result_status = problem.solve()

# 結果をまとめる
count = [pulp.value(var) for var in var_ary]

# 結果表示
print('-' * 100)
print('<計算結果>')
print(f"最適性 : {pulp.LpStatus[result_status]}")
print(f"{objective_name} : {pulp.value(problem.objective)}")
# Out:
# 問題:
# MINIMIZE
# 0.165*var0 + 0.752*var1 + 17.12*var2 + 0.64*var3 + 0.0097*var4 + 1.327*var5 + 0.983*var6 + 0.39666666666666667*var7 + 7.375*var8 + 5.414285714285715*var9 + 0.0
# SUBJECT TO
# 総カロリー_エネルギー_kcalの下限: 1.681 var0 + 4.429 var1 + 34 var2 + 0.2 var3 + 0.003 var4
#  + 3.589 var5 + 9.25 var6 + 0.921 var7 + 1.665 var8 + 1.45 var9 >= 2500
#
# 総カロリー_エネルギー_kcalの上限: 1.681 var0 + 4.429 var1 + 34 var2 + 0.2 var3 + 0.003 var4
#  + 3.589 var5 + 9.25 var6 + 0.921 var7 + 1.665 var8 + 1.45 var9 <= 2600
#
# 三大栄養素_タンパク質_gの下限: 0.025 var0 + 0.356 var1 + 2 var2 + 0.022 var3 + 0.34 var5
#  + 0.073 var9 >= 60
#
# 三大栄養素_タンパク質_gの上限: 0.025 var0 + 0.356 var1 + 2 var2 + 0.022 var3 + 0.34 var5
#  + 0.073 var9 <= 125
#
# ビタミン_ビタミンA_μgの下限: 2.99 var2 + 3.5 var3 + 0.06 var5 + 0.15 var6 + 0.002 var7
#  + 225 var8 + 150 var9 >= 600
#
# ビタミン_ビタミンA_μgの上限: 2.99 var2 + 3.5 var3 + 0.06 var5 + 0.15 var6 + 0.002 var7
#  + 225 var8 + 150 var9 <= 2700
#
# ビタミン_ビタミンD_μgの下限: 5 var8 >= 8.5
#
# ビタミン_ビタミンD_μgの上限: 5 var8 <= 100
#
# ビタミン_ビタミンE_mgの下限: 0.01 var1 + 0.05 var2 + 0.021 var3 + 0.074 var6
#  + 0.0024 var7 + 4.5 var8 >= 6
#
# ビタミン_ビタミンE_mgの上限: 0.01 var1 + 0.05 var2 + 0.021 var3 + 0.074 var6
#  + 0.0024 var7 + 4.5 var8 <= 850
#
# ビタミン_ビタミンK_μgの下限: 0.37 var1 + 32.96 var2 + 2.7 var3 + 0.42 var6 + 0.005 var7
#  >= 150
#
# ビタミン_ビタミンB1_mgの下限: 0.007 var1 + 0.03 var2 + 0.001 var3 + 0.003 var5
#  + 0.75 var8 >= 1.35
#
# ビタミン_ビタミンB2_mgの下限: 0.003 var1 + 0.03 var2 + 0.002 var3 + 0.016 var5
#  + 0.85 var8 >= 1.5
#
# ビタミン_ナイアシン_mgの下限: 0.002 var0 + 0.019 var1 + 1.64 var2 + 0.006 var3
#  + 0.011 var5 + 7.5 var8 >= 14.4
#
# ビタミン_ナイアシン_mgの上限: 0.002 var0 + 0.019 var1 + 1.64 var2 + 0.006 var3
#  + 0.011 var5 + 7.5 var8 <= 80
#
# ビタミン_ビタミンB6_mgの下限: 0.006 var1 + 0.02 var2 + 0.001 var3 + 0.003 var5 + var8
#  >= 1.42
#
# ビタミン_ビタミンB6_mgの上限: 0.006 var1 + 0.02 var2 + 0.001 var3 + 0.003 var5 + var8
#  <= 55
#
# ビタミン_ビタミンB12_μgの下限: 0.49 var2 + 0.018 var5 + 1.5 var8 >= 2.4
#
# ビタミン_葉酸_μgの下限: 0.03 var0 + 2.5 var1 + 4.47 var2 + 2.1 var3 + 0.01 var5
#  + 120 var8 >= 240
#
# ビタミン_葉酸_μgの上限: 0.03 var0 + 2.5 var1 + 4.47 var2 + 2.1 var3 + 0.01 var5
#  + 120 var8 <= 900
#
# ビタミン_パントテン酸_mgの下限: 0.003 var0 + 0.013 var1 + 0.05 var2 + 0.002 var3
#  + 0.042 var5 + 3 var8 >= 5
#
# ビタミン_ビオチン_μgの下限: 0.005 var0 + 1.22 var2 + 0.029 var3 + 0.187 var5 + 25 var8
#  >= 50
#
# ビタミン_ビタミンC_mgの下限: 0.35 var3 + 0.05 var5 + 62.5 var8 >= 100
#
# ミネラル_カリウム_mgの下限: 0.29 var0 + 19 var1 + 150.41 var2 + 6.9 var3 + 18 var5
#  >= 2500
#
# ミネラル_カルシウム_mgの下限: 0.03 var0 + 2.5 var1 + 30.8 var2 + 0.49 var3 + 11 var5
#  + 0.001 var7 + 100 var8 >= 664.3
#
# ミネラル_カルシウム_mgの上限: 0.03 var0 + 2.5 var1 + 30.8 var2 + 0.49 var3 + 11 var5
#  + 0.001 var7 + 100 var8 <= 2500
#
# ミネラル_マグネシウム_mgの下限: 0.07 var0 + 2.4 var1 + 18.44 var2 + 0.69 var3 + 1.1 var5
#  + 50 var8 >= 334.8
#
# ミネラル_リン_mgの下限: 0.34 var0 + 5.2 var1 + 42.2 var2 + 0.47 var3 + 10 var5
#  + 0.001 var7 >= 1000
#
# ミネラル_リン_mgの上限: 0.34 var0 + 5.2 var1 + 42.2 var2 + 0.47 var3 + 10 var5
#  + 0.001 var7 <= 3000
#
# ミネラル_鉄_mgの下限: 0.001 var0 + 0.091 var1 + 0.52 var2 + 0.02 var3 + 0.005 var5
#  + 0.0001 var7 + 2 var8 >= 7.1
#
# ミネラル_鉄_mgの上限: 0.001 var0 + 0.091 var1 + 0.52 var2 + 0.02 var3 + 0.005 var5
#  + 0.0001 var7 + 2 var8 <= 50
#
# ミネラル_亜鉛_mgの下限: 0.006 var0 + 0.036 var1 + 0.17 var2 + 0.007 var3 + 0.039 var5
#  + 3 var8 >= 10.62
#
# ミネラル_亜鉛_mgの上限: 0.006 var0 + 0.036 var1 + 0.17 var2 + 0.007 var3 + 0.039 var5
#  + 3 var8 <= 40
#
# ミネラル_銅_mgの下限: 0.001 var0 + 0.011 var1 + 0.03 var2 + 0.001 var3 + 0.001 var5
#  + 0.3 var8 >= 0.81
#
# ミネラル_銅_mgの上限: 0.001 var0 + 0.011 var1 + 0.03 var2 + 0.001 var3 + 0.001 var5
#  + 0.3 var8 <= 7
#
# ミネラル_マンガン_mgの下限: 0.004 var0 + 0.003 var3 + 1e-05 var7 >= 3.5
#
# ミネラル_マンガン_mgの上限: 0.004 var0 + 0.003 var3 + 1e-05 var7 <= 11
#
# ミネラル_ヨウ素_μgの下限: 170 var2 + 0.03 var3 + 1.2 var5 >= 130
#
# ミネラル_ヨウ素_μgの上限: 170 var2 + 0.03 var3 + 1.2 var5 <= 3000
#
# ミネラル_セレン_μgの下限: 0.01 var0 + 0.4 var2 + 0.03 var3 + 0.27 var5 + 25 var8 >= 30.8
#
# ミネラル_セレン_μgの上限: 0.01 var0 + 0.4 var2 + 0.03 var3 + 0.27 var5 + 25 var8 <= 450
#
# ミネラル_クロム_μgの下限: 0.44 var2 + 0.02 var3 + 0.01 var5 + 10 var8 >= 10
#
# ミネラル_クロム_μgの上限: 0.44 var2 + 0.02 var3 + 0.01 var5 + 10 var8 <= 500
#
# ミネラル_モリブデン_μgの下限: 0.3 var0 + 4.16 var2 + 0.05 var3 + 0.35 var5 >= 30
#
# ミネラル_モリブデン_μgの上限: 0.3 var0 + 4.16 var2 + 0.05 var3 + 0.35 var5 <= 600
#
# その他_食塩相当量_gの下限: 1.37 var2 + 0.1 var4 + 0.014 var5 >= 2
#
# その他_食塩相当量_gの上限: 1.37 var2 + 0.1 var4 + 0.014 var5 <= 7.5
#
# その他_食物繊維_総量_gの下限: 0.003 var0 + 0.169 var1 + 1.37 var2 + 0.028 var3 >= 19.8
#
# 脂肪酸_n_3系_多価不飽和_gの下限: 0.019 var1 + 0.05 var2 + 0.001 var3 + 0.006 var6
#  + 0.061 var7 >= 2.5
#
# 脂肪酸_n_6系_多価不飽和_gの下限: 0.001 var0 + 0.109 var1 + 0.19 var2 + 0.067 var6
#  + 0.013 var7 >= 5
#
# 脂肪酸_脂肪酸_飽和_gの上限: 0.001 var0 + 0.034 var1 + 0.07 var2 + 0.004 var5 + 0.133 var6
#  + 0.0076 var7 <= 19.4
#
# n_6/n_3: 0.001 var0 + 0.071 var1 + 0.09 var2 - 0.002 var3 + 0.055 var6
#  - 0.109 var7 <= 0
#
# ネイチャーメイド_スーパーマルチビタミン&ミネラル_は1粒まで: var8 <= 2
#
# わかめの味噌汁_は一杯: var2 = 1
#
# オリーブオイルで一価と多価を同量にする: 0 var0 + 0.08 var1 + 0.19 var2 + 0.002 var3 - 0.002 var5
#  - 0.668 var6 + 0.0537 var7 <= 0
#
# VARIABLES
# 0 <= var0 <= 9.22337203685e+18 Integer
# 0 <= var1 <= 9.22337203685e+18 Integer
# 0 <= var2 <= 9.22337203685e+18 Integer
# 0 <= var3 <= 9.22337203685e+18 Integer
# 0 <= var4 <= 9.22337203685e+18 Integer
# 0 <= var5 <= 9.22337203685e+18 Integer
# 0 <= var6 <= 9.22337203685e+18 Integer
# 0 <= var7 <= 9.22337203685e+18 Integer
# 0 <= var8 <= 9.22337203685e+18 Integer
# 0 <= var9 <= 9.22337203685e+18 Integer
#
# ----------------------------------------------------------------------------------------------------
# <計算結果>
# 最適性 : Optimal
# 価格（税込） : 364.14778571428576

# %% [markdown]
# # 詳細を表示

# %%
'''
個数を df にする
下のセルでも使う
'''

df_count = pd.DataFrame(count, index=df_data['食品情報_食品名'], columns=['個数'])
display(df_count)
# Out:
#                                個数
# 食品情報_食品名
# ご飯                         1066.0
# きな粉                          86.0
# わかめの味噌汁                       1.0
# ほうれんそう                       29.0
# 塩                             5.0
# スキムミルク                       16.0
# オリーブオイル                      17.0
# えごま油                         75.0
# ネイチャーメイド スーパーマルチビタミン&ミネラル     2.0
# ネイチャーメイド ベータカロテン              1.0

# %%
'''栄養素の合計値・合計値の下限値に対する割合・合計値の上限値に対する割合'''

# 下限値に対する割合・上限値に対する割合
df_total = (df_data.loc[:, df_constraint.index].T * df_count.values.flatten()).sum(axis=1).to_frame()
df_total.columns = ['合計値']
df_ratio = pd.DataFrame(df_total.values.flatten()/df_constraint.values.T, index=['下限値に対する割合', '上限値に対する割合'], columns=df_total.index).T.round(2)

# 合計値
i = df_data.columns.tolist().index('総カロリー_エネルギー_kcal')
dff = df_data.iloc[:, i:]
dff = pd.DataFrame((dff.T.values * df_count['個数'].values), dff.columns, df_data['食品情報_食品名']).T
dff = dff.T.sum(axis=1).to_frame()
dff.columns = ['合計値']

# 下限値・上限値と一緒にまとめる
dff = pd.concat([dff, df_constraint, df_ratio], axis=1)

# 栄養素名を分解
dff['栄養カテゴリ'] = dff.index.map(lambda x: x.split('_')[0])
dff['栄養素名'] = dff.index.map(lambda x: x.split('_')[1])
dff['単位'] = dff.index.map(lambda x: x.split('_')[2])
dff.index = dff['栄養カテゴリ']
dff = dff.loc[:, ['栄養素名', '単位', '合計値', '下限値', '下限値に対する割合', '上限値', '上限値に対する割合']]

# 表示を整える
dff = dff.replace(np.nan, '-')

# 表示
pd.set_option('display.max_rows', dff.shape[0])
display(dff)
pd.reset_option('display.max_rows')
# Out:
# /Users/satoshikawaguchi/python/python_env/py3env/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# 三大栄養素                     脂質     g     48.66000      -         -     -
# 総カロリー                  エネルギー  kcal   2501.18400   2500         1  2600
# 脂肪酸               18:1-オレイン酸    mg  18285.76000      -         -     -
# 脂肪酸           18:2-n-6-リノール酸    mg  12818.90000      -         -     -
# 脂肪酸         18:3-n-3-α－リノレン酸    mg   6342.87000      -         -     -
# 脂肪酸         18:3-n-6-γ－リノレン酸    mg      0.59000      -         -     -
# 脂肪酸     18:4-n-3-オクタデカテトラエン酸    mg      9.40000      -         -     -
# 脂肪酸         20:2-n-6-イコサジエン酸    mg      0.29000      -         -     -
# 脂肪酸        20:3-n-6-イコサトリエン酸    mg      0.49000      -         -     -
# 脂肪酸       20:4-n-3-イコサテトラエン酸    mg      0.00000      -         -     -
# 脂肪酸          20:4-n-6-アラキドン酸    mg      5.12000      -         -     -
# 脂肪酸       20:5-n-3-イコサペンタエン酸    mg      4.59000      -         -     -
# 脂肪酸     21:5-n-3-ヘンイコサペンタエン酸    mg      0.00000      -         -     -
# 脂肪酸       22:4-n-6-ドコサテトラエン酸    mg      0.00000      -         -     -
# 脂肪酸       22:5-n-3-ドコサペンタエン酸    mg      0.00000      -         -     -
# 脂肪酸       22:5-n-6-ドコサペンタエン酸    mg      0.00000      -         -     -
# 脂肪酸       22:6-n-3-ドコサヘキサエン酸    mg      0.00000      -         -     -
# 脂肪酸               n-3系-多価不飽和     g      6.39000    2.5      2.56     -
# 脂肪酸               n-6系-多価不飽和     g     12.74400      5      2.55     -
# 脂肪酸                脂肪酸-一価不飽和     g     18.95150      -         -     -
# 脂肪酸                脂肪酸-多価不飽和     g     18.71900      -         -     -
# 脂肪酸                   脂肪酸-総量     g     44.67600      -         -     -
# 脂肪酸                   脂肪酸-飽和     g      6.95500      -         -  19.4
#
#        上限値に対する割合
# 栄養カテゴリ
# その他         0.28
# その他            -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# アミノ酸           -
# ビタミン        0.26
# ビタミン           -
# ビタミン           -
# ビタミン        0.26
# ビタミン           -
# ビタミン           -
# ビタミン           -
# ビタミン        0.05
# ビタミン           -
# ビタミン         0.1
# ビタミン        0.01
# ビタミン           -
# ビタミン        0.61
# ミネラル           -
# ミネラル        0.27
# ミネラル        0.04
# ミネラル        0.15
# ミネラル           -
# ミネラル           -
# ミネラル         0.4
# ミネラル        0.55
# ミネラル        0.06
# ミネラル        0.34
# ミネラル        0.41
# ミネラル        0.28
# ミネラル        0.38
# 三大栄養素       0.52
# 三大栄養素          -
# 三大栄養素          -
# 総カロリー       0.96
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸            -
# 脂肪酸         0.36

# %%
'''食品ごとの下限値に対する割合・上限値に対する割合'''

for i_constraint_column, limit_name in enumerate(['下限値', '上限値']):
    
    # 食品ごとの下限値に対する割合・上限値に対する割合 を作成
    dff       = df_data.loc[:, df_constraint.index] * df_count.values
    dff.index = df_data['食品情報_食品名']
    df_ratio  = dff / df_constraint.iloc[:, i_constraint_column].values
    
    # 全部nanの栄養素は除外
    df_ratio = df_ratio.dropna(axis=1, how='all')
    
    # 個数が0以上の食品を抽出
    df_ratio = df_ratio.loc[df_count.index[(df_count > 0).values.flatten()], :]
    df_ratio.index.name = '食品'
    df_ratio.columns.name = '栄養素'

    # 見やすい順番に並べ替え
    index = [
        'ネイチャーメイド スーパーマルチビタミン&ミネラル',
        'ネイチャーメイド ベータカロテン',
        'スキムミルク',
        'オリーブオイル',
        '塩',
        'ご飯',
        'わかめの味噌汁',
        'えごま油',
        'きな粉',
        'ほうれんそう',
    ]
    set_df      = set(df_ratio.index.tolist())
    set_setting = set(index)
    print('設定されていないもの　　  : ', set_df - set_setting)
    print('0個なのに設定しているもの : ', set_setting - set_df)
    if len(set_df - set_setting) + len(set_setting - set_df) != 0:
        raise
    df_ratio = df_ratio.loc[index, :]
    
    # 描画
    df_ratio.T.plot.barh(y=df_ratio.index.tolist(), figsize=(40,20), stacked=True, cmap='viridis')
    
    if limit_name == '下限値':
        plt.xticks(np.arange(plt.xlim()[1]))
    elif limit_name == '上限値':
        plt.xticks(np.arange(11)/10)
    else:
        raise
        
    plt.grid(which='both', axis='x')
    plt.xlabel(f'{limit_name}に対する割合')
    plt.tight_layout() # なぜかこれすると grid の色がまばらなのが直る
    plt.show()
# Out:
# 設定されていないもの　　  :  set()
# 0個なのに設定しているもの :  set()
# 設定されていないもの　　  :  set()
# 0個なのに設定しているもの :  set()

# %%
'''食品ごとの栄養素の合計値'''

i = df_data.columns.tolist().index('総カロリー_エネルギー_kcal')
df_num = df_data.iloc[:, i:]
df_detail = pd.DataFrame((df_num.T.values * df_count['個数'].values), df_num.columns, df_data['食品情報_食品名']).T

pd.set_option('display.max_columns', df_num.shape[1])
display(df_detail)
pd.reset_option('display.max_columns')
# Out:
#                            総カロリー_エネルギー_kcal  三大栄養素_タンパク質_g  三大栄養素_脂質_g  \
# 食品情報_食品名
# ご飯                                 1791.946         26.650       3.198
# きな粉                                 380.894         30.616      20.124
# わかめの味噌汁                              34.000          2.000       0.440
# ほうれんそう                                5.800          0.638       0.116
# 塩                                     0.015          0.000       0.000
# スキムミルク                               57.424          5.440       0.160
# オリーブオイル                             157.250          0.000      17.000
# えごま油                                 69.075          0.000       7.500
# ネイチャーメイド スーパーマルチビタミン&ミネラル             3.330          0.000       0.000
# ネイチャーメイド ベータカロテン                      1.450          0.073       0.122
#
#                            三大栄養素_炭水化物_g  ビタミン_ビタミンA_μg  ビタミン_ビタミンD_μg  \
# 食品情報_食品名
# ご飯                             395.4860           0.00            0.0
# きな粉                             26.6600           0.00            0.0
# わかめの味噌汁                          5.8600           2.99            0.0
# ほうれんそう                           0.8990         101.50            0.0
# 塩                                0.0035           0.00            0.0
# スキムミルク                           8.5280           0.96            0.0
# オリーブオイル                          0.0000           2.55            0.0
# えごま油                             0.0000           0.15            0.0
# ネイチャーメイド スーパーマルチビタミン&ミネラル        0.6710         450.00           10.0
# ネイチャーメイド ベータカロテン                 0.0000         150.00            0.0
#
#                            ビタミン_ビタミンE_mg  ビタミン_ビタミンK_μg  ビタミン_ビタミンB1_mg  \
# 食品情報_食品名
# ご飯                                 0.000          0.000           0.000
# 食品情報_食品名
# ご飯                                               0.0
# きな粉                                              0.0
# わかめの味噌汁                                          0.0
# ほうれんそう                                           0.0
# 塩                                                0.0
# スキムミルク                                           0.0
# オリーブオイル                                          0.0
# えごま油                                             0.0
# ネイチャーメイド スーパーマルチビタミン&ミネラル                        0.0
# ネイチャーメイド ベータカロテン                                 0.0
#
#                            脂肪酸_22:5-n-6-ドコサペンタエン酸_mg  \
# 食品情報_食品名
# ご飯                                               0.0
# きな粉                                              0.0
# わかめの味噌汁                                          0.0
# ほうれんそう                                           0.0
# 塩                                                0.0
# スキムミルク                                           0.0
# オリーブオイル                                          0.0
# えごま油                                             0.0
# ネイチャーメイド スーパーマルチビタミン&ミネラル                        0.0
# ネイチャーメイド ベータカロテン                                 0.0
#
#                            脂肪酸_22:6-n-3-ドコサヘキサエン酸_mg  脂肪酸_n-3系-多価不飽和_g  \
# 食品情報_食品名
# ご飯                                               0.0             0.000
# きな粉                                              0.0             1.634
# わかめの味噌汁                                          0.0             0.050
# ほうれんそう                                           0.0             0.029
# 塩                                                0.0             0.000
# スキムミルク                                           0.0             0.000
# オリーブオイル                                          0.0             0.102
# えごま油                                             0.0             4.575
# ネイチャーメイド スーパーマルチビタミン&ミネラル                        0.0             0.000
# ネイチャーメイド ベータカロテン                                 0.0             0.000
#
#                            脂肪酸_n-6系-多価不飽和_g  脂肪酸_脂肪酸-一価不飽和_g  脂肪酸_脂肪酸-多価不飽和_g  \
# 食品情報_食品名
# ご飯                                    1.066           1.0660            1.066
# きな粉                                   9.374           3.9560           10.836
# わかめの味噌汁                               0.190           0.0500            0.240
# ほうれんそう                                0.000           0.0000            0.058
# 塩                                     0.000           0.0000            0.000
# スキムミルク                                0.000           0.0320            0.000
# オリーブオイル                               1.139          12.5800            1.224
# えごま油                                  0.975           1.2675            5.295
# ネイチャーメイド スーパーマルチビタミン&ミネラル             0.000           0.0000            0.000
# ネイチャーメイド ベータカロテン                      0.000           0.0000            0.000
#
#                            脂肪酸_脂肪酸-総量_g  脂肪酸_脂肪酸-飽和_g
# 食品情報_食品名
# ご飯                                3.198         1.066
# きな粉                              17.716         2.924
# わかめの味噌汁                           0.370         0.070
# ほうれんそう                            0.058         0.000
# 塩                                 0.000         0.000
# スキムミルク                            0.112         0.064
# オリーブオイル                          16.082         2.261
# えごま油                              7.140         0.570
# ネイチャーメイド スーパーマルチビタミン&ミネラル         0.000         0.000
# ネイチャーメイド ベータカロテン                  0.000         0.000

# %%
'''食品ごとの価格（税込）'''

price_ary = (df_data['価格（税込）'].values * df_count.values.flatten())
pd.DataFrame(price_ary, index=df_data['食品情報_食品名'], columns=['価格（税込）'])
# Out:
#                                価格（税込）
# 食品情報_食品名
# ご飯                         175.890000
# きな粉                         64.672000
# わかめの味噌汁                     17.120000
# ほうれんそう                      18.560000
# 塩                            0.048500
# スキムミルク                      21.232000
# オリーブオイル                     16.711000
# えごま油                        29.750000
# ネイチャーメイド スーパーマルチビタミン&ミネラル   14.750000
# ネイチャーメイド ベータカロテン             5.414286
